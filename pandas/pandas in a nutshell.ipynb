# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
this = Series([6,5,4,9,2])
this
# Out:
# 0    6
# 1    5
# 2    4
# 3    9
# 4    2
# dtype: int64

# %%
citypopulation = Series([8537673,3976322,2704958,2303482,1615017], 
                        index=['NYC','Los Angeles','Chicago','Houston','Phoenix'])

# %%
citypopulation[citypopulation<2500000]
# Out:
# Houston    2303482
# Phoenix    1615017
# dtype: int64

# %%
'Chicago' in citypopulation
# Out:
# True

# %%
citypopulation['NYC']
# Out:
# 8537673

# %%
cities = ['NYC','Los Angeles','Chicago','Houston','Phoenix','Philadelhia']
Ser = Series(citypopulation,index=cities)

# %%
Ser.isnull()
# Out:
# NYC            False
# Los Angeles    False
# Chicago        False
# Houston        False
# Phoenix        False
# Philadelhia     True
# dtype: bool

# %%
Ser1 = Ser+citypopulation

# %%
Ser1.name = "Us City Populations"
Ser1.index.name = "Cities"

# %%
Ser1
# Out:
# Cities
# Chicago         5409916.0
# Houston         4606964.0
# Los Angeles     7952644.0
# NYC            17075346.0
# Philadelhia           NaN
# Phoenix         3230034.0
# Name: Us City Populations, dtype: float64

# %%
df = pd.read_csv("https://raw.githubusercontent.com/data-is-plural/mls-salaries/master/csvs/mls-salaries-2016.csv")

# %%
df
# Out:
#     club     last_name first_name position  base_salary  \
# 0    ATL        Burgos     Efrain        M     62508.00
# 1    ATL  Oblitey Otoo    Jeffrey        M     51504.00
# 2    ATL      Tambakis  Alexander       GK     63000.00
# 3    CHI         Accam      David      F-M    700000.00
# 4    CHI       Alvarez     Arturo        F    115000.00
# 5    CHI      Calistri       Joey        M     51500.00
# 6    CHI      Campbell   Jonathan        D     70000.00
# 7    CHI         Cocis     Razvan        M    160000.00
# 8    CHI        Conner       Drew        M     62500.00
# 9    CHI         Doody    Patrick        D     53471.00
# 10   CHI     Fernandez     Collin        M     75000.00
# 11   CHI        Gehrig       Eric        D    106875.00
# 12   CHI      Goossens       John        M    200000.00
# 13   CHI    Harrington    Michael        D    125000.00
# 14   CHI   Igboananike    Kennedy        F    800000.00
# 15   CHI       Johnson       Sean       GK    250000.00
# 16   CHI        Junior   Gilberto        F   1145000.00
# 17   CHI     Kappelhof      Johan        D    480000.00
# 18   CHI      LaBrocca       Nick        M    110000.00
# 19   CHI       Lampson       Matt       GK     71250.00
# 20   CHI        McLain    Patrick       GK     72500.00
# 21   CHI         Meira       Joao      D-M    110000.00
# 22   CHI       Morrell       Alex        M     51500.00
# 23   CHI       Polster       Matt      D-M     84000.00
# 24   CHI         Ramos    Rodrigo        D     80000.00
# 25   CHI      Stephens    Michael        M    105000.00
# 26   CHI         Thiam      Khaly        M    144000.00
# 27   CHI       Vincent    Brandon        D     70000.00
# 28   CLB         Afful   Harrison        D    275000.00
# 29   CLB          Ashe      Corey        D     95000.00
# ..   ...           ...        ...      ...          ...
# 525  VAN      Carducci      Marco       GK     63000.00
# 526  VAN          Dean  Christian        D    110000.00
# 527  VAN        Flores      Deybi        M     62500.00
# 528  VAN        Froese      Kianz        M     66000.00
# 529  VAN        Harvey     Jordan        D    165000.00
# 530  VAN       Hurtado       Erik      F/M     86091.50
# 531  VAN      Jacobson     Andrew        M     62500.08
# 532  VAN           Kah   Pa Modou        D     97000.00
# 533  VAN          Kudo     Masato        F    310000.00
# 534  VAN          Laba     Matias        M    560000.00
# 535  VAN        Manneh     Kekuta      M-F    127500.00
# 536  VAN      McKendry        Ben        M     52500.00
# 537  VAN      Mezquida    Nicolas      M-F     88000.00
# 538  VAN       Morales      Pedro        M   1232500.00
# 539  VAN        Ousted      David       GK    360000.00
# 540  VAN        Parker        Tim        D     66000.00
# 541  VAN         Perez       Blas        F    215000.00
# 542  VAN        Rivero    Octavio        F    890850.00
# 543  VAN        Seiler       Cole        D     51500.00
# 544  VAN         Smith     Jordan        D    115000.00
# 545  VAN       Techera   Cristian        M    320000.00
# 546  VAN       Teibert    Russell        M    115000.00
# 547  VAN      Tornaghi      Paolo       GK     62500.00
# 548  VAN        Waston    Kendall        D    300000.00
# 549  NaN        Gargan        Dan        D    145000.00
# 550  NaN      Martinez   Cristian        M     62508.00
# 551  NaN         Moore       Luke        F    115000.00
# 552  NaN        Nyassi      Sanna        M    135000.00
# 553  NaN        Ovalle     Adolfo        M     63000.00
# 554  NaN        Tshuma    Schillo        F     81999.96
#
#      guaranteed_compensation
# 0                   62508.00
# 1                   51504.00
# 2                   63000.00
# 3                  770937.50
# 4                  118264.00
# 5                   51500.00
# 6                   78125.00
# 7                  160000.00
# 8                   62500.00
# 9                   53471.00
# 10                  77000.00
# 11                 112708.33
# 12                 200000.00
# 13                 125000.00
# 14                 901666.67
# 15                 253000.00
# 16                1145000.00
# 17                 520000.00
# 18                 110000.00
# 19                  76625.00
# 20                  72500.00
# 21                 126500.00
# 22                  51500.00
# 23                  99000.00
# 24                  84000.00
# 25                 115000.00
# 26                 144000.00
# 27                  91875.00
# 28                 291666.67
# 29                 105500.00
# ..                       ...
# 525                 63000.00
# 526                191000.00
# 527                 68385.00
# 528                 70500.00
# 529                165000.00
# 530                121091.50
# 531                 87500.08
# 532                101850.00
# 533                314000.00
# 534                720500.00
# 535                157000.00
# 536                 52500.00
# 537                 88000.00
# 538               1258900.00
# 539                378933.33
# 540                 84750.00
# 541                215000.00
# 542                890850.00
# 543                 51500.00
# 544                122743.00
# 545                345000.00
# 546                182500.00
# 547                 62500.00
# 548                318125.00
# 549                145000.00
# 550                 67008.00
# 551                137500.00
# 552                141250.00
# 553                 73500.00
# 554                119999.96
#
# [555 rows x 6 columns]

# %%
df.head()
# Out:
#   club     last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL        Burgos     Efrain        M      62508.0                  62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0                  51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0                  63000.0
# 3  CHI         Accam      David      F-M     700000.0                 770937.5
# 4  CHI       Alvarez     Arturo        F     115000.0                 118264.0

# %%
df.tail()
# Out:
#     club last_name first_name position  base_salary  guaranteed_compensation
# 550  NaN  Martinez   Cristian        M     62508.00                 67008.00
# 551  NaN     Moore       Luke        F    115000.00                137500.00
# 552  NaN    Nyassi      Sanna        M    135000.00                141250.00
# 553  NaN    Ovalle     Adolfo        M     63000.00                 73500.00
# 554  NaN    Tshuma    Schillo        F     81999.96                119999.96

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 555 entries, 0 to 554
# Data columns (total 6 columns):
# club                       549 non-null object
# last_name                  555 non-null object
# first_name                 553 non-null object
# position                   555 non-null object
# base_salary                555 non-null float64
# guaranteed_compensation    555 non-null float64
# dtypes: float64(2), object(4)
# memory usage: 26.1+ KB

# %%
df['last_name'].head()
# Out:
# 0          Burgos
# 1    Oblitey Otoo
# 2        Tambakis
# 3           Accam
# 4         Alvarez
# Name: last_name, dtype: object

# %%
DataFrame(df,columns=['last_name', 'first_name', 'Age'])
# Out:
#         last_name first_name  Age
# 0          Burgos     Efrain  NaN
# 1    Oblitey Otoo    Jeffrey  NaN
# 2        Tambakis  Alexander  NaN
# 3           Accam      David  NaN
# 4         Alvarez     Arturo  NaN
# 5        Calistri       Joey  NaN
# 6        Campbell   Jonathan  NaN
# 7           Cocis     Razvan  NaN
# 8          Conner       Drew  NaN
# 9           Doody    Patrick  NaN
# 10      Fernandez     Collin  NaN
# 11         Gehrig       Eric  NaN
# 12       Goossens       John  NaN
# 13     Harrington    Michael  NaN
# 14    Igboananike    Kennedy  NaN
# 15        Johnson       Sean  NaN
# 16         Junior   Gilberto  NaN
# 17      Kappelhof      Johan  NaN
# 18       LaBrocca       Nick  NaN
# 19        Lampson       Matt  NaN
# 20         McLain    Patrick  NaN
# 21          Meira       Joao  NaN
# 22        Morrell       Alex  NaN
# 23        Polster       Matt  NaN
# 24          Ramos    Rodrigo  NaN
# 25       Stephens    Michael  NaN
# 26          Thiam      Khaly  NaN
# 27        Vincent    Brandon  NaN
# 28          Afful   Harrison  NaN
# 29           Ashe      Corey  NaN
# ..            ...        ...  ...
# 525      Carducci      Marco  NaN
# 526          Dean  Christian  NaN
# 527        Flores      Deybi  NaN
# 528        Froese      Kianz  NaN
# 529        Harvey     Jordan  NaN
# 530       Hurtado       Erik  NaN
# 531      Jacobson     Andrew  NaN
# 532           Kah   Pa Modou  NaN
# 533          Kudo     Masato  NaN
# 534          Laba     Matias  NaN
# 535        Manneh     Kekuta  NaN
# 536      McKendry        Ben  NaN
# 537      Mezquida    Nicolas  NaN
# 538       Morales      Pedro  NaN
# 539        Ousted      David  NaN
# 540        Parker        Tim  NaN
# 541         Perez       Blas  NaN
# 542        Rivero    Octavio  NaN
# 543        Seiler       Cole  NaN
# 544         Smith     Jordan  NaN
# 545       Techera   Cristian  NaN
# 546       Teibert    Russell  NaN
# 547      Tornaghi      Paolo  NaN
# 548        Waston    Kendall  NaN
# 549        Gargan        Dan  NaN
# 550      Martinez   Cristian  NaN
# 551         Moore       Luke  NaN
# 552        Nyassi      Sanna  NaN
# 553        Ovalle     Adolfo  NaN
# 554        Tshuma    Schillo  NaN
#
# [555 rows x 3 columns]

# %%
df.head()
# Out:
#   club     last_name first_name position  base_salary  guaranteed_compensation
# 0  ATL        Burgos     Efrain        M      62508.0                  62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0                  51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0                  63000.0
# 3  CHI         Accam      David      F-M     700000.0                 770937.5
# 4  CHI       Alvarez     Arturo        F     115000.0                 118264.0

# %%
df.ix[4]
# Out:
# club                           CHI
# last_name                  Alvarez
# first_name                  Arturo
# position                         F
# base_salary                 115000
# guaranteed_compensation     118264
# Name: 4, dtype: object

# %%
df['double_salary'] = df['base_salary']*2

# %%
df.head()
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M      62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0
# 3  CHI         Accam      David      F-M     700000.0
# 4  CHI       Alvarez     Arturo        F     115000.0
#
#    guaranteed_compensation  double_salary
# 0                  62508.0       125016.0
# 1                  51504.0       103008.0
# 2                  63000.0       126000.0
# 3                 770937.5      1400000.0
# 4                 118264.0       230000.0

# %%
df['stuff'] = 'Stuff'

# %%
df.head()
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M      62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0
# 3  CHI         Accam      David      F-M     700000.0
# 4  CHI       Alvarez     Arturo        F     115000.0
#
#    guaranteed_compensation  double_salary  stuff
# 0                  62508.0       125016.0  Stuff
# 1                  51504.0       103008.0  Stuff
# 2                  63000.0       126000.0  Stuff
# 3                 770937.5      1400000.0  Stuff
# 4                 118264.0       230000.0  Stuff

# %%
tax = Series(['Good Stuff', 'Bad Stuff'],index=[0,6])

# %%
df['stuff'] = tax

# %%
df.head(10)
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M      62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0
# 3  CHI         Accam      David      F-M     700000.0
# 4  CHI       Alvarez     Arturo        F     115000.0
# 5  CHI      Calistri       Joey        M      51500.0
# 6  CHI      Campbell   Jonathan        D      70000.0
# 7  CHI         Cocis     Razvan        M     160000.0
# 8  CHI        Conner       Drew        M      62500.0
# 9  CHI         Doody    Patrick        D      53471.0
#
#    guaranteed_compensation  double_salary       stuff
# 0                  62508.0       125016.0  Good Stuff
# 1                  51504.0       103008.0         NaN
# 2                  63000.0       126000.0         NaN
# 3                 770937.5      1400000.0         NaN
# 4                 118264.0       230000.0         NaN
# 5                  51500.0       103000.0         NaN
# 6                  78125.0       140000.0   Bad Stuff
# 7                 160000.0       320000.0         NaN
# 8                  62500.0       125000.0         NaN
# 9                  53471.0       106942.0         NaN

# %%
del df['stuff']

# %%
df.head()
# Out:
#   club     last_name first_name position  base_salary  \
# 0  ATL        Burgos     Efrain        M      62508.0
# 1  ATL  Oblitey Otoo    Jeffrey        M      51504.0
# 2  ATL      Tambakis  Alexander       GK      63000.0
# 3  CHI         Accam      David      F-M     700000.0
# 4  CHI       Alvarez     Arturo        F     115000.0
#
#    guaranteed_compensation  double_salary
# 0                  62508.0       125016.0
# 1                  51504.0       103008.0
# 2                  63000.0       126000.0
# 3                 770937.5      1400000.0
# 4                 118264.0       230000.0

# %%
Myfruits = {'fruits':['Orange','Mango','Grapes','Guava'],'Price' :[20,50,90,100]}

# %%
dffruits = DataFrame(Myfruits)

# %%
dffruits
# Out:
#    Price  fruits
# 0     20  Orange
# 1     50   Mango
# 2     90  Grapes
# 3    100   Guava

# %%
df = Series([6,4,5,9,7],index=['Red','Blue','Green','Brown','Violet'])
df
# Out:
# Red       6
# Blue      4
# Green     5
# Brown     9
# Violet    7
# dtype: int64

# %%
df.reindex(['Red','Blue','Green','Brown','Violet','Pink'])
# Out:
# Red       6.0
# Blue      4.0
# Green     5.0
# Brown     9.0
# Violet    7.0
# Pink      NaN
# dtype: float64

# %%
df.reindex(['Red','Blue','Green','Brown','Violet','Pink'],fill_value=10)
# Out:
# Red        6
# Blue       4
# Green      5
# Brown      9
# Violet     7
# Pink      10
# dtype: int64

# %%
df = DataFrame(np.random.random_integers(25,size=25).reshape((5,5)),index=['A','B','D','E','F'],
                   columns=['col1','col2','col3','col4','col5'])


df
# Out:
# /usr/local/lib/python3.6/site-packages/ipykernel_launcher.py:2: DeprecationWarning: This function is deprecated. Please call randint(1, 25 + 1) instead
#    col1  col2  col3  col4  col5
# A     8     1     3    16    10
# B     2     9    22     1    11
# D     6    13    17     6    23
# E     2     2     5    16    12
# F    23     7    17    19     6

# %%
df.sum(axis=1)
# Out:
# A    38
# B    45
# D    65
# E    37
# F    72
# dtype: int64

# %%
df.sum(axis=0)
# Out:
# col1    41
# col2    32
# col3    64
# col4    58
# col5    62
# dtype: int64

# %%
df.describe()
# Out:
#             col1      col2       col3       col4       col5
# count   5.000000   5.00000   5.000000   5.000000   5.000000
# mean    8.200000   6.40000  12.800000  11.600000  12.400000
# std     8.671793   4.97996   8.318654   7.700649   6.348228
# min     2.000000   1.00000   3.000000   1.000000   6.000000
# 25%     2.000000   2.00000   5.000000   6.000000  10.000000
# 50%     6.000000   7.00000  17.000000  16.000000  11.000000
# 75%     8.000000   9.00000  17.000000  16.000000  12.000000
# max    23.000000  13.00000  22.000000  19.000000  23.000000

# %%
corr=df.corr()
corr
# Out:
#           col1      col2      col3      col4      col5
# col1  1.000000  0.038208  0.160111  0.596749 -0.483193
# col2  0.038208  1.000000  0.853317 -0.672770  0.610491
# col3  0.160111  0.853317  1.000000 -0.653304  0.148650
# col4  0.596749 -0.672770 -0.653304  1.000000 -0.532878
# col5 -0.483193  0.610491  0.148650 -0.532878  1.000000

# %%
import seaborn as sns
# %matplotlib inline
sns.heatmap(corr)

# %%
dframe = DataFrame([[5,4,3,2,7],[6,3,np.NaN,np.NAN,9],[np.NaN,3,4,2,np.NaN]])

dframe
# Out:
#      0  1    2    3    4
# 0  5.0  4  3.0  2.0  7.0
# 1  6.0  3  NaN  NaN  9.0
# 2  NaN  3  4.0  2.0  NaN

# %%
df1=df.dropna(axis=1)
df1
# Out:
#    col1  col2  col3  col4  col5
# A     8     1     3    16    10
# B     2     9    22     1    11
# D     6    13    17     6    23
# E     2     2     5    16    12
# F    23     7    17    19     6

# %%
df.fillna(5)
# Out:
#    col1  col2  col3  col4  col5
# A     8     1     3    16    10
# B     2     9    22     1    11
# D     6    13    17     6    23
# E     2     2     5    16    12
# F    23     7    17    19     6

# %%
df.drop('B')
# Out:
#    col1  col2  col3  col4  col5
# A     8     1     3    16    10
# D     6    13    17     6    23
# E     2     2     5    16    12
# F    23     7    17    19     6

# %%
df[['col1','col2']]
# Out:
#    col1  col2
# A     8     1
# B     2     9
# D     6    13
# E     2     2
# F    23     7

# %%
df.ix['D']
# Out:
# col1     6
# col2    13
# col3    17
# col4     6
# col5    23
# Name: D, dtype: int64

# %%
df[df['col1']>10]
# Out:
#    col1  col2  col3  col4  col5
# F    23     7    17    19     6

# %%
df=Series([6,4,3,2],index=['A','B','C','D'])
df
# Out:
# A    6
# B    4
# C    3
# D    2
# dtype: int64

# %%
df['C']
# Out:
# 3

# %%
df[0:2]
# Out:
# A    6
# B    4
# dtype: int64

# %%
df=Series([6,4,2,1],index=['P','R','S','Q'])
df
# Out:
# P    6
# R    4
# S    2
# Q    1
# dtype: int64

# %%
df.sort_index()
# Out:
# P    6
# Q    1
# R    4
# S    2
# dtype: int64

# %%
df.sort_values()
# Out:
# Q    1
# S    2
# R    4
# P    6
# dtype: int64

# %%
df.rank()
# Out:
# P    4.0
# R    3.0
# S    2.0
# Q    1.0
# dtype: float64

# %%
Sr = Series([5,4,3,7,9,6],index=[[1,1,2,2,3,3],['a','b','a','b','a','b']])
Sr
# Out:
# 1  a    5
#    b    4
# 2  a    3
#    b    7
# 3  a    9
#    b    6
# dtype: int64

# %%
Sr.index
# Out:
# MultiIndex(levels=[[1, 2, 3], ['a', 'b']],
#            labels=[[0, 0, 1, 1, 2, 2], [0, 1, 0, 1, 0, 1]])

# %%
Sr[3]
# Out:
# a    9
# b    6
# dtype: int64

# %%
Sr[:,'b']
# Out:
# 1    4
# 2    7
# 3    6
# dtype: int64

# %%
Sr.unstack()
# Out:
#    a  b
# 1  5  4
# 2  3  7
# 3  9  6
