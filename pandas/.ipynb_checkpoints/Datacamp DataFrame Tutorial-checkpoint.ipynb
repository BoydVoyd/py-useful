# %%
import pandas as pd
import numpy as np
from pandas import Series, DataFrame

# %%
macs_df = pd.read_csv('353 Computers in All Macs.csv')

# %%
macs_df
# Out:
#                      Computer Name  Operating System Master Password Set  \
# 0              admin’s MacBook Air  Mac OS X 10.12.6               False
# 1          admin’s MacBook Air (2)  Mac OS X 10.12.3               False
# 2              admin’s MacBook Pro  Mac OS X 10.12.2               False
# 3                          Alberto  Mac OS X 10.12.5               False
# 4                  AmyW-RAML202222  Mac OS X 10.12.6               False
# 5                          anacron  Mac OS X 10.12.6                True
# 6                       BKMD202045  Mac OS X 10.12.6               False
# 7                       BOMD105299  Mac OS X 10.11.6               False
# 8                       BOML105140  Mac OS X 10.12.2               False
# 9                       BOML105140  Mac OS X 10.12.4               False
# 10                      BOML105149  Mac OS X 10.10.2               False
# 11                      boml105155  Mac OS X 10.11.6               False
# ...

# %%
print(macs_df['Model'])
# Out:
# 0                       MacBook Air (13-inch Early 2015)
# 1                       MacBook Air (13-inch Early 2015)
# 2                  15-inch Retina MacBook Pro (Mid 2015)
# 3                       MacBook Air (13-inch Early 2015)
# 4                       MacBook Air (13-inch Early 2015)
# 5                 15-inch Retina MacBook Pro (Late 2013)
# 6              iMac Intel (Retina 5k, 27-inch, Mid 2017)
# 7                                   Mac mini (Late 2012)
# 8                         MacBook Air (13-inch Mid 2013)
# 9                       MacBook Air (13-inch Early 2015)
# 10                15-inch Retina MacBook Pro (Late 2013)
# 11                 15-inch Retina MacBook Pro (Mid 2012)
# 12                15-inch Retina MacBook Pro (Late 2013)
# 13                15-inch Retina MacBook Pro (Late 2013)
# 14                        MacBook Air (13-inch Mid 2013)
# 15                        MacBook Air (13-inch Mid 2013)
# ...
